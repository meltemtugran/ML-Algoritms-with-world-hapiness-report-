# %% [markdown]
# <a href="https://colab.research.google.com/github/meltemtugran/ML-Algoritms-with-world-hapiness-report-/blob/main/world_hapiness_report_data2_2021.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt
data2 = pd.read_csv('2021.csv')

# %%
data3 = pd.read_csv('2015.csv')

# %% [markdown]
# #sütun isimlerni aaynı yapma

# %%
data3.rename(columns={'Country ': 'country', 
                   
                   'Region':'region',
                 
                   'Economy (GDP per capita)' :'economy', 
                   'Family': 'social_support',
                   'Healthy (Life Expectancy)':'healthy_life',
                   'Freedom ':'freedom',
                   'Generosity':'generosity',
                   'Trust (Government Corruption)':'corruption',
                   
                  }, inplace=True)

# %%
data3 = data3.drop('Happiness Rank', axis = 1)
data3 = data3.drop('Standard Error', axis = 1)
data3 = data3.drop('Dystopia Residual', axis = 1)

# %%
a=data3[data3['Country']=='Turkey']

# %%
a.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
b=data2[data2['Country name']=='Turkey']

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=a,x="y",data=b,y="Ladder score",marker='o')
plt.title("Hapiness Score")
plt.show()

# %%
f,ax = plt.subplots(figsize=(10, 10))
sns.heatmap(data3.corr(), annot=True, linewidths=.7, fmt= '.2f',ax=ax)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x='Happiness Score', y='Freedom', data=data3, ci=None);
plt.title('Correlation between hapiness score and freedom', fontsize=20, fontweight='bold', pad=20);

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x='Happiness Score', y='corruption', data=data3, ci=None);
plt.title('Correlation between hapiness score and corruption', fontsize=20, fontweight='bold', pad=20);

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x='Happiness Score', y='Health (Life Expectancy)', data=data3, ci=None);
plt.title('Correlation between hapiness score and healty', fontsize=20, fontweight='bold', pad=20);

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x='Happiness Score', y='social_support', data=data3, ci=None);
plt.title('Correlation between hapiness score and social support', fontsize=20, fontweight='bold', pad=20);

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x='Happiness Score', y='Economy (GDP per Capita)', data=data3, ci=None);
plt.title('Correlation between hapiness score and economy', fontsize=20, fontweight='bold', pad=20);

# %%
plt.figure(figsize=(12, 6))
sns.regplot(x='Happiness Score', y='generosity', data=data3, ci=None);
plt.title('Correlation between hapiness score and generosity', fontsize=20, fontweight='bold', pad=20);

# %%
data2.rename(columns={'Country name': 'country', 
                   'Regional indicator':'region', 
                   'Ladder score':'ladder_score',
                   'Standard error of ladder score':'standart_error', 
                   'Logged GDP per capita' :'economy', 
                   'Social support': 'social_support',
                   'Healthy life expectancy':'healthy_life',
                   'Freedom to make life choices':'freedom',
                   'Generosity':'generosity',
                   'Perceptions of corruption':'corruption',
                   'Ladder score in Dystopia':'ladder_score_dystopia',
                   'Explained by: Log GDP per capita':'explained_economy', 
                   'Explained by: Social support':'explained_social_support',
                   'Explained by: Healthy life expectancy':'explained_healthy_life',
                   'Explained by: Freedom to make life choices':'explained_freedom',
                   'Explained by: Generosity':'explained_generosity',
                   'Explained by: Perceptions of corruption':'explained_corruption',
                   'Dystopia + residual':'dystopia_resid'
                  }, inplace=True)

# %%
data2.region
# Out:
# 0          Western Europe
# 1          Western Europe
# 2          Western Europe
# 3          Western Europe
# 4          Western Europe
#               ...
# 144    Sub-Saharan Africa
# 145    Sub-Saharan Africa
# 146    Sub-Saharan Africa
# 147    Sub-Saharan Africa
# 148            South Asia
# Name: region, Length: 149, dtype: object

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(data2.corr(), annot=True, linewidths=.7, fmt= '.2f',ax=ax)
plt.show()

# %% [markdown]
# #DÜNYA BÖLGELERİDNE LİFE SATİCFİCTİON

# %%
data2.columns
# Out:
# Index(['country', 'region', 'ladder_score', 'standart_error', 'upperwhisker',
#        'lowerwhisker', 'economy', 'social_support', 'healthy_life', 'freedom',
#        'generosity', 'corruption', 'ladder_score_dystopia',
#        'explained_economy', 'explained_social_support',
#        'explained_healthy_life', 'explained_freedom', 'explained_generosity',
#        'explained_corruption', 'dystopia_resid'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(12,8))

sns.barplot(x='economy',y='country',data=data2.nlargest(10,'economy'),ax=axes[0,0],palette="Blues_d")
sns.barplot(x='social_support' ,y='country',data=data2.nlargest(10,'social_support'),ax=axes[1,0],palette='OrRd')
sns.barplot(x='social_support' ,y='country',data=data2.nsmallest(10,'social_support'),ax=axes[1,0],palette='OrRd')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(12,8))


sns.barplot(x='ladder_score' ,y='country',data=data2.nlargest(10,'ladder_score'),ax=axes[1,0],palette='OrRd')
sns.barplot(x='healthy_life' ,y='country',data=data2.nlargest(10,'healthy_life'),ax=axes[1,0],palette='OrRd')

# %%
data3.columns
# Out:
# Index(['Country', 'region', 'Happiness Score', 'Economy (GDP per Capita)',
#        'social_support', 'Health (Life Expectancy)', 'Freedom', 'corruption',
#        'generosity'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['country', 'region', 'ladder_score', 'standart_error', 'upperwhisker',
#        'lowerwhisker', 'economy', 'social_support', 'healthy_life', 'freedom',
#        'generosity', 'corruption', 'ladder_score_dystopia',
#        'explained_economy', 'explained_social_support',
#        'explained_healthy_life', 'explained_freedom', 'explained_generosity',
#        'explained_corruption', 'dystopia_resid'],
#       dtype='object')

# %%
plt.figure(figsize=(30,5))
sns.lineplot(data=data2,x="region",y="ladder_score",marker='o')
plt.title("Hapiness Score")
plt.show()

# %%
plt.figure(figsize=(30,5))
sns.lineplot(data=data3,x="region",y="Happiness Score",marker='o')
plt.title("Life Ladder")
plt.show()

# %%
data2.region
# Out:
# 50      Central and Eastern Europe
# 51     Latin America and Caribbean
# 52      Central and Eastern Europe
# 53                  Southeast Asia
# 54     Latin America and Caribbean
#                   ...
# 144             Sub-Saharan Africa
# 145             Sub-Saharan Africa
# 146             Sub-Saharan Africa
# 147             Sub-Saharan Africa
# 148                     South Asia
# Name: region, Length: 99, dtype: object

# %% [markdown]
# #sütunları silme eşitleme

# %%
data2.columns
# Out:
# Index(['country', 'region', 'ladder_score', 'standart_error', 'upperwhisker',
#        'lowerwhisker', 'economy', 'social_support', 'healthy_life', 'freedom',
#        'generosity', 'corruption', 'ladder_score_dystopia',
#        'explained_economy', 'explained_social_support',
#        'explained_healthy_life', 'explained_freedom', 'explained_generosity',
#        'explained_corruption', 'dystopia_resid'],
#       dtype='object')

# %%
data2 = data2.drop('standart_error', axis = 1)
data2 = data2.drop('ladder_score_dystopia', axis = 1)
data2 = data2.drop('upperwhisker', axis = 1)
data2 = data2.drop('dystopia_resid', axis = 1)
data2 = data2.drop('lowerwhisker', axis = 1)
data2 = data2.drop('explained_freedom', axis = 1)
data2 = data2.drop('explained_generosity', axis = 1)
data2 = data2.drop('explained_corruption', axis = 1)
data2 = data2.drop('explained_economy', axis = 1)
data2 = data2.drop('explained_social_support', axis = 1)
data2 = data2.drop('explained_healthy_life', axis = 1)
data2 = data2.iloc[50:]
data2.columns
# Out:
# Index(['country', 'region', 'ladder_score', 'economy', 'social_support',
#        'healthy_life', 'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
b=data2[data2['region']=='South Asia']

# %% [markdown]
# #KORELASYON

# %% [markdown]
# pandeminin etkisiyle  ekonomi,social support health mululuğa etkisi artmıştır. diğer yıllara före

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(data2.corr(), annot=True, linewidths=.7, fmt= '.2f',ax=ax)
plt.show()

# %%
data2.columns
# Out:
# Index(['country', 'region', 'ladder_score', 'economy', 'social_support',
#        'healthy_life', 'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
data2.region.unique()
# Out:
# array(['Central and Eastern Europe', 'Latin America and Caribbean',
#        'Southeast Asia', 'East Asia', 'Western Europe',
#        'Commonwealth of Independent States',
#        'Middle East and North Africa', 'Sub-Saharan Africa', 'South Asia'],
#       dtype=object)

# %%
data3.region.unique()
# Out:
# array(['Latin America and Caribbean', 'Central and Eastern Europe',
#        'Southeastern Asia', 'Middle East and Northern Africa',
#        'Western Europe', 'Sub-Saharan Africa', 'Eastern Asia',
#        'Southern Asia'], dtype=object)

# %% [markdown]
# #life ladder en yüksek olan 3 bölge -ülke grafiği

# %%
data2.columns
# Out:
# Index(['country', 'region', 'ladder_score', 'economy', 'social_support',
#        'healthy_life', 'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
data2.region.unique()
# Out:
# array(['Central and Eastern Europe', 'Latin America and Caribbean',
#        'Southeast Asia', 'East Asia', 'Western Europe',
#        'Commonwealth of Independent States',
#        'Middle East and North Africa', 'Sub-Saharan Africa', 'South Asia'],
#       dtype=object)

# %%
western_europe=data2[data2['region']== 'Western Europe']

# %%
north_america=data2[data2['region']== 'Commonwealth of Independent States']
Latin_America_Caribbean=data2[data2['region']== 'Latin America and Caribbean']
Central_Eastern_Europe=data2[data2['region']== 'Central and Eastern Europe']

# %%
middle_east=data2[data2['region']== 'Middle East and North Africa']

# %%
plt.figure(figsize = (20,5))
plt.xticks(rotation=90)
sns.lineplot(x="country", y = "ladder_score", data = western_europe,marker ='o',label='western_europe')
sns.lineplot(x="country", y = "ladder_score", data = north_america,marker ='o',label='north_america')
sns.lineplot(x="country", y = "ladder_score", data = Latin_America_Caribbean,marker ='o',label='latin_america')
sns.lineplot(x="country", y = "ladder_score", data = Central_Eastern_Europe,marker ='o',label='Central_Eastern_Europe')
plt.show()

# %%
data2.region.unique()
# Out:
# array(['Central and Eastern Europe', 'Latin America and Caribbean',
#        'Southeast Asia', 'East Asia', 'Western Europe',
#        'Commonwealth of Independent States',
#        'Middle East and North Africa', 'Sub-Saharan Africa', 'South Asia'],
#       dtype=object)

# %%
middle_east_north_Africa=data2[data2['region']== 'Middle East and North Africa']
Southeast_Asia=data2[data2['region']== 'Southeast Asia']
East_Asia=data2[data2['region']== 'East Asia']
Commonwealth_of_Independent_States=data2[data2['region']== 'Commonwealth of Independent States']
Sub_Saharan_Africa=data2[data2['region']== 'Sub Saharan Africa']
South_Asia=data2[data2['region']== 'South Asia']

# %%
plt.figure(figsize = (20,5))
plt.xticks(rotation=90)
sns.lineplot(x="country", y = "ladder_score", data =middle_east_north_Africa,marker ='o',label='middle_east_north_Africa')
sns.lineplot(x="country", y = "ladder_score", data = Southeast_Asia,marker ='o',label='Southeast_Asia')
sns.lineplot(x="country", y = "ladder_score", data = East_Asia,marker ='o',label='East_Asia')
sns.lineplot(x="country", y = "ladder_score", data = Commonwealth_of_Independent_States,marker ='o',label='Commonwealth_of_Independent_States')
plt.show()

# %%
plt.figure(figsize = (20,5))
plt.xticks(rotation=90)
sns.lineplot(x="country", y = "ladder_score", data =middle_east_north_Africa,marker ='o',label='middle_east_north_Africa')
plt.show()

# %%
plt.figure(figsize = (16,8))
plt.xticks(rotation=90)
sns.lineplot(x="country", y = "ladder_score", data = western_europe,marker ='o',label='western_europe')
sns.lineplot(x="country", y = "ladder_score", data = north_america,marker ='o',label='north_america')
sns.lineplot(x="country", y = "ladder_score", data = middle_east,marker ='o',label='middle_east')
plt.show()

# %%
print("(Rows, columns): " + str(data2.shape))
data2.columns
# Out:
# (Rows, columns): (49, 9)
# Index(['country', 'region', 'ladder_score', 'GDP', 'social_support',
#        'healthy_life', 'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['country', 'region', 'ladder_score', 'economy', 'social_support',
#        'healthy_life', 'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
data2 = data2.'region'.drop('East Asia', axis = 1)
# Out:
#   File "<ipython-input-110-36f55084db60>", line 1
#     data2 = data2.'region'.drop('East Asia', axis = 1)
#                          ^
# SyntaxError: invalid syntax

# %%
sns.pairplot(data=data2, size = 5, hue='region',
                  x_vars=['ladder_score'],
                  y_vars=['economy', 'social_support','healthy_life', 'freedom', 'generosity', 'corruption', ])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
data3.columns
# Out:
# Index(['Country', 'region', 'Happiness Score', 'Economy (GDP per Capita)',
#        'social_support', 'Health (Life Expectancy)', 'Freedom', 'corruption',
#        'generosity'],
#       dtype='object')

# %%
fig, axes = plt.subplots(nrows=2, ncols=2,constrained_layout=True,figsize=(12,8))

sns.barplot(x='Economy',y='Country',data=data3.nlargest(10,'Economy'),ax=axes[0,0],palette="Blues_d")


sns.barplot(x='healthy_life' ,y='country',data=data3.nlargest(10,'healthy_life'),ax=axes[1,0],palette='OrRd')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897             try:
# -> 2898                 return self._engine.get_loc(casted_key)
#    2899             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'economy'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-ce91b1548f34> in <module>()
# ...
