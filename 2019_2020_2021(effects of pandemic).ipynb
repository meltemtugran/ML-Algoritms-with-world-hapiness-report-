# %% [markdown]
# <a href="https://colab.research.google.com/github/meltemtugran/ML-Algoritms-with-world-hapiness-report-/blob/main/2019_2020_2021(effects%20of%20pandemic).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns
import matplotlib.pyplot as plt
d1 = pd.read_csv('2019.csv')
d2 = pd.read_csv('2020.csv')
d3 = pd.read_csv('2021.csv')
d4=pd.read_csv('2015.csv')
d5=pd.read_csv('2017.csv')
d6=pd.read_csv('2018.csv')

# %%
d6.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
a=d1[d1['Country or region']=='Turkey']
b=d2[d2['Country name']=='Turkey']
c=d3[d3['Country name']=='Turkey']
d=d4[d4['Country']=='Turkey']
e=d5[d5['Country']=='Turkey']
f=d6[d6['Country or region']=='Turkey']

# %%
d.head()
# Out:
#    Country                           Region  ...  Generosity  Dystopia Residual
# 75  Turkey  Middle East and Northern Africa  ...     0.12253            2.08528
#
# [1 rows x 12 columns]

# %%
e.head()
# Out:
#    Country  Happiness.Rank  ...  Trust..Government.Corruption.  Dystopia.Residual
# 68  Turkey              69  ...                       0.099672           1.879278
#
# [1 rows x 12 columns]

# %%
f.head()
# Out:
#     Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 73            74            Turkey  ...       0.106                      0.109
#
# [1 rows x 9 columns]

# %%
a.head()
# Out:
#     Overall rank Country or region  ...  Generosity  Perceptions of corruption
# 78            79            Turkey  ...       0.083                      0.106
#
# [1 rows x 9 columns]

# %%
b.head()
# Out:
#    Country name  ... Dystopia + residual
# 92       Turkey  ...            1.564817
#
# [1 rows x 20 columns]

# %%
c.head()
# Out:
#     Country name  ... Dystopia + residual
# 103       Turkey  ...               1.852
#
# [1 rows x 20 columns]

# %%
d1.rename(columns={
                   'Country or region': 'country',
                   'Score':'hapiness_score',

                   'GDP per capita':'economy',
                    
                   
                   'Logged GDP per capita' :'economy', 
                   'Social support': 'social_support',
                   'Healthy life expectancy':'healthy_life',
                   'Freedom to make life choices':'freedom',
                   'Generosity':'generosity',
                   'Perceptions of corruption':'corruption',
                   
                   
                   
                  }, inplace=True)

# %%
d3.rename(columns={'Country name': 'country', 
                   'Regional indicator': 'region',
                   'Standard error of ladder score':'error',

                   'Ladder score':'hapiness_score',
                    'Ladder score in Dystopia':'siil1',
                   
                   'Logged GDP per capita' :'economy', 
                   'Social support': 'social_support',
                   'Healthy life expectancy':'healthy_life',
                   'Freedom to make life choices':'freedom',
                   'Generosity':'generosity',
                   'Perceptions of corruption':'corruption',
                   'Explained by: Log GDP per capita': 'sil2',
                   'Explained by: Social support': 'sil3',
       'Explained by: Healthy life expectancy': 'sil4',
       'Explained by: Freedom to make life choices': 'sil5',
       'Explained by: Generosity': 'sil6', 
       'Explained by: Perceptions of corruption':'sil7',
       'Dystopia + residual': 'sil8'
                   
                   
                  }, inplace=True)

# %%
d3 = d3.drop('region', axis = 1)
d3 = d3.drop('error', axis = 1)
d3 = d3.drop('siil1', axis = 1)
d3 = d3.drop('sil2', axis = 1)
d3 = d3.drop('sil3', axis = 1)
d3 = d3.drop('sil4', axis = 1)
d3 = d3.drop('sil5', axis = 1)
d3 = d3.drop('sil6', axis = 1)
d3 = d3.drop('sil7', axis = 1)
d3 = d3.drop('sil8', axis = 1)
d3 = d3.drop('upperwhisker', axis = 1)
d3 = d3.drop('lowerwhisker', axis = 1)

# %%
d2.rename(columns={'Country name': 'country', 
                   'Regional indicator': 'region',
                   'Standard error of ladder score':'error',

                   'Ladder score':'hapiness_score',
                    'Ladder score in Dystopia':'siil1',
                   
                   'Logged GDP per capita' :'economy', 
                   'Social support': 'social_support',
                   'Healthy life expectancy':'healthy_life',
                   'Freedom to make life choices':'freedom',
                   'Generosity':'generosity',
                   'Perceptions of corruption':'corruption',
                   'Explained by: Log GDP per capita': 'sil2',
                   'Explained by: Social support': 'sil3',
       'Explained by: Healthy life expectancy': 'sil4',
       'Explained by: Freedom to make life choices': 'sil5',
       'Explained by: Generosity': 'sil6', 
       'Explained by: Perceptions of corruption':'sil7',
       'Dystopia + residual': 'sil8'
                   
                   
                  }, inplace=True)

# %%
d1=d1.drop('Overall rank',axis = 1)

# %%
d2 = d2.drop('siil1', axis = 1)
d2 = d2.drop('sil2', axis = 1)
d2 = d2.drop('sil3', axis = 1)
d2 = d2.drop('sil4', axis = 1)
d2 = d2.drop('sil5', axis = 1)
d2 = d2.drop('sil6', axis = 1)
d2 = d2.drop('sil7', axis = 1)
d2 = d2.drop('sil8', axis = 1)
d2 = d2.drop('region', axis = 1)
d2 = d2.drop('error', axis = 1)
d2 = d2.drop('upperwhisker', axis = 1)
d2 = d2.drop('lowerwhisker', axis = 1)

# %%
d1.columns

# %%
d1.head()

# %%
d2.head()

# %%
d3.head()

# %%
d4.columns

# %%
d4=d4.drop('Standard Error',axis = 1)
d4=d4.drop('Happiness Rank',axis = 1)
d4=d4.drop('Dystopia Residual',axis = 1)

# %%
d4.rename(columns={'Country': 'country', 
                   'Regional': 'region',
                   

                   'Happiness score':'hapiness_score',
                    'Economy (GDP per Capita)' :'economy', 
                   'Social support': 'social_support',
                   'Health (Life Expectancy)' : 'healthy_life',
                   'Freedom':'freedom',
                   'Generosity':'generosity',
                   'Trust (Government Corruption)':'corruption',
                   
      
       
                   
                   
                  }, inplace=True)

# %%
d4.columns

# %%
a=d1[d1['country']=='Turkey']
b=d2[d2['country']=='Turkey']
c=d3[d3['country']=='Turkey']
d=d4[d4['country']=='Turkey']
a.head()

# %%
b.head()

# %%
c.head()

# %%
d.head()

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(d1.corr(), annot=True, linewidths=.7, fmt= '.2f',ax=ax)
plt.show()

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(d2.corr(), annot=True, linewidths=.7, fmt= '.2f',ax=ax)
plt.show()

# %%
f,ax = plt.subplots(figsize=(15, 15))
sns.heatmap(d3.corr(), annot=True, linewidths=.7, fmt= '.2f',ax=ax)
plt.show()

# %%
d1.columns
# Out:
# Index(['country', 'hapiness_score', 'economy', 'social_support',
#        'healthy_life', 'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data=d1.nlargest(10,'healthy_life'),x="country",y="healthy_life",marker='o')
plt.title("Healthy")
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.lineplot(data=d1.nsmallest(10,'healthy_life'),x="country",y="healthy_life",marker='o')
plt.title("Healthy")
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.lineplot(data=d3.nlargest(10,'healthy_life'),x="country",y="healthy_life",marker='o')
plt.title("Healthy")
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.lineplot(data=d2.nlargest(10,'healthy_life'),x="country",y="healthy_life",marker='o')
plt.title("Healthy")
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.lineplot(data=d1.nlargest(10,'healthy_life'),x="country",y="healthy_life",marker='o')
plt.title("Healthy")
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.lineplot(data=d1.nlargest(10,'hapiness_score'),x="country",y="hapiness_score",marker='o')
plt.title("Hapiness Score")
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.lineplot(data=d2.nlargest(10,'hapiness_score'),x="country",y="hapiness_score",marker='o')
plt.title("Hapiness Score")
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.lineplot(data=d3.nlargest(10,'hapiness_score'),x="country",y="hapiness_score",marker='o')
plt.title("Hapiness Score")
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=d1.nsmallest(10,'hapiness_score'),x="country",y="hapiness_score",marker='o')
plt.title("Hapiness Score")
plt.show()

# %%
d3 = d3.drop('siil1', axis = 1)
d3 = d3.drop('sil2', axis = 1)
d3 = d3.drop('sil3', axis = 1)
d3 = d3.drop('sil4', axis = 1)
d3 = d3.drop('sil5', axis = 1)
d3 = d3.drop('sil6', axis = 1)
d3 = d3.drop('sil7', axis = 1)
d3 = d3.drop('sil8', axis = 1)
d3 = d3.drop('region', axis = 1)
d3 = d3.drop('error', axis = 1)
d3 = d3.drop('upperwhisker', axis = 1)
d3 = d3.drop('lowerwhisker', axis = 1)

# %%
d3.columns
# Out:
# Index(['country', 'ladder_score', 'economy', 'social_support', 'healthy_life',
#        'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
d4.columns
# Out:
# Index(['country', 'ladder_score', 'economy', 'social_support', 'healthy_life',
#        'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
d4.columns
# Out:
# Index(['country', 'ladder_score', 'economy', 'social_support', 'healthy_life',
#        'freedom', 'generosity', 'corruption'],
#       dtype='object')

# %%
print(d1.isna().sum())
# Out:
# country           0
# ladder_score      0
# economy           0
# social_support    0
# healthy_life      0
# freedom           0
# generosity        0
# corruption        0
# dtype: int64

# %%
print(d2.isna().sum())
# Out:
# country           0
# ladder_score      0
# economy           0
# social_support    0
# healthy_life      0
# freedom           0
# generosity        0
# corruption        0
# dtype: int64

# %%
print(d3.isna().sum())
# Out:
# country           0
# ladder_score      0
# economy           0
# social_support    0
# healthy_life      0
# freedom           0
# generosity        0
# corruption        0
# dtype: int64

# %%
print(d4.isna().sum())
# Out:
# country           0
# ladder_score      0
# economy           0
# social_support    0
# healthy_life      0
# freedom           0
# generosity        0
# corruption        0
# dtype: int64
